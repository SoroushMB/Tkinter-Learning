# %%
#Tkinter version
from tkinter import *

# Initial Settings
cal = Tk()
cal.title("Calculator")


# Funcitons Part
def btnClick(numbers):
    global operator
    operator = operator + str(numbers)
    text_input.set(operator)
def btnClearDisplay():
    global operator
    operator = ""
    text_input.set("")
def btnEqualsInput():
    global operator
    sumup = str(eval(operator))
    text_input.set(sumup)
    operator=""
operator = ""
text_input = StringVar()

# Main Display Part
txtDisplay = Entry(cal,
    font=('JetBrains Mono',20,'bold'),
    textvariable=text_input,
    bd=30,
    insertwidth=4,
    bg='powder blue',
    justify='right')
# Setting Up the First Column Of Buttons 
btn7 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='7', relief=RAISED, command=lambda:btnClick(7))
btn8 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='8', relief=RAISED, command=lambda:btnClick(8))
btn9 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='9', relief=RAISED, command=lambda:btnClick(9))
addition = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='+', relief=RAISED, command=lambda:btnClick('+'))

# Setting Up the Second Column Of Buttons
btn4 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='4', relief=RAISED, command=lambda:btnClick(4))
btn5 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='5', relief=RAISED, command=lambda:btnClick(5))
btn6 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='6', relief=RAISED, command=lambda:btnClick(6))
subtraction = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='-', relief=RAISED, command=lambda:btnClick('-'))

# Setting Up the Third Column Of Buttons
btn1 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='1', relief=RAISED, command=lambda:btnClick(1))
btn2 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='2', relief=RAISED, command=lambda:btnClick(2))
btn3 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='3', relief=RAISED, command=lambda:btnClick(3))
multiply = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='*', relief=RAISED, command=lambda:btnClick('*'))

# Setting Up the Fourth Column Of Buttons
btn0 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='0', relief=RAISED, command=lambda:btnClick(0))
btnClear = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='C', relief=RAISED, command=btnClearDisplay)
btnEquals = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='=', relief=RAISED, command=btnEqualsInput)
division = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('JetBrains Mono',20,'bold'), text='/', relief=RAISED, command=lambda:btnClick('/'))

# Griding Everything In Order
btn7.grid(row=1 , column=0 )
btn8.grid(row=1 , column=1 )
btn9.grid(row=1 , column=2 )
addition.grid(row=1 , column=3 )
btn4.grid(row=2 , column=0 )
btn5.grid(row=2 , column=1 )
btn6.grid(row=2 , column=2 )
subtraction.grid(row=2 , column=3 )
btn1.grid(row=3 , column=0 )
btn2.grid(row=3 , column=1 )
btn3.grid(row=3 , column=2 )
multiply.grid(row=3 , column=3 )
btn0.grid(row=4 , column=0 )
btnClear.grid(row=4, column=1)
btnEquals.grid(row=4 , column=2)
division.grid(row=4 , column=3)

cal.mainloop()

# %%
#CustomTkinter Version
from customtkinter import *

#Tkinter version
# from tkinter import *

# Initial Settings
cal = CTk()
cal.title("Calculator")
set_default_color_theme('blue')
set_appearance_mode('dark')
# Funcitons Part
def btnClick(numbers):
    global operator
    operator = operator + str(numbers)
    text_input.set(operator)
def btnClearDisplay():
    global operator
    operator = ""
    text_input.set("")
def btnEqualsInput():
    global operator
    sumup = str(eval(operator))
    text_input.set(sumup)
    operator=""
operator = ""
text_input = StringVar()

# Main Display Part
txtDisplay = CTkEntry(cal,
    font=('JetBrains Mono',20,'bold'),
    textvariable=text_input,
    border_width=30,
    insertwidth=4,
    fg_color='powder blue',
    justify='right')
# Setting Up the First Column Of Buttons 
btn7 = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='7', command=lambda:btnClick(7))
btn8 = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='8', command=lambda:btnClick(8))
btn9 = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='9', command=lambda:btnClick(9))
addition = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='+', command=lambda:btnClick('+'))

# Setting Up the Second Column Of Buttons
btn4 = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='4', command=lambda:btnClick(4))
btn5 = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='5', command=lambda:btnClick(5))
btn6 = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='6', command=lambda:btnClick(6))
subtraction = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='-', command=lambda:btnClick('-'))

# Setting Up the Third Column Of Buttons
btn1 = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='1', command=lambda:btnClick(1))
btn2 = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='2', command=lambda:btnClick(2))
btn3 = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='3', command=lambda:btnClick(3))
multiply = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='*', command=lambda:btnClick('*'))

# Setting Up the Fourth Column Of Buttons
btn0 = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='0', command=lambda:btnClick(0))
btnClear = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='C', command=btnClearDisplay)
btnEquals = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='=', command=btnEqualsInput)
division = CTkButton(cal, width=16, height=16, border_width=8, font=('JetBrains Mono',20,'bold'), text='/', command=lambda:btnClick('/'))

# Griding Everything In Order
btn7.grid(row=1 , column=0 )
btn8.grid(row=1 , column=1 )
btn9.grid(row=1 , column=2 )
addition.grid(row=1 , column=3 )
btn4.grid(row=2 , column=0 )
btn5.grid(row=2 , column=1 )
btn6.grid(row=2 , column=2 )
subtraction.grid(row=2 , column=3 )
btn1.grid(row=3 , column=0 )
btn2.grid(row=3 , column=1 )
btn3.grid(row=3 , column=2 )
multiply.grid(row=3 , column=3 )
btn0.grid(row=4 , column=0 )
btnClear.grid(row=4, column=1)
btnEquals.grid(row=4 , column=2)
division.grid(row=4 , column=3)

cal.mainloop()
